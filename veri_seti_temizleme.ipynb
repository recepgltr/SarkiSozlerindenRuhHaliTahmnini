# %%
import pandas as pd
import re
import nltk
import string
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f5056a8c-e0b4-4570-ba12-f46d38fc45c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5056a8c-e0b4-4570-ba12-f46d38fc45c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("mutlu.csv")  # Eğer farklı isimle yüklendiyse, o ismi yaz
df.head()
# Out:
#                artist    song_title  \
# 0              Tarkan     Kuzu Kuzu
# 1        Kenan Doğulu       Çakkıdı
# 2         Ajda Pekkan   Yaz Yaz Yaz
# 3  Nil Karaibrahimgil      Pırlanta
# 4          Sezen Aksu  Hadi Bakalım
#
#                                               lyrics   mood
# 0  11 ContributorsKuzu Kuzu Lyrics\n\nBak\nKırıld...  mutlu
# 1  6 ContributorsÇakkıdı Lyrics\nBuralardan hemen...  mutlu
# 2  5 ContributorsYaz Yaz Yaz LyricsDuygular var h...  mutlu
# 3  2 ContributorsPırlanta LyricsParan cebinde kal...  mutlu
# 4  5 ContributorsHadi Bakalım Lyrics\n\nYerimiz m...  mutlu

# %%
def temizle(metin):
    if pd.isna(metin):
        return ""
    metin = metin.lower()

    # "contributors" ve "lyrics" gibi kalıpları kaldır
    metin = re.sub(r"contributors", "", metin)
    metin = re.sub(r"lyrics", "", metin)

    # Geri kalan temizlik işlemleri
    metin = re.sub(r"http\S+|www.\S+", "", metin)
    metin = re.sub(r"\d+", "", metin)
    metin = metin.translate(str.maketrans("", "", string.punctuation))
    metin = re.sub(r"\s+", " ", metin).strip()
    kelimeler = metin.split()
    kelimeler = [kelime for kelime in kelimeler if kelime not in stop_words]
    return " ".join(kelimeler)

# %%
df["temiz_lyrics"] = df["lyrics"].apply(temizle)
df[["lyrics", "temiz_lyrics"]].head()
# Out:
#                                               lyrics  \
# 0  11 ContributorsKuzu Kuzu Lyrics\n\nBak\nKırıld...
# 1  6 ContributorsÇakkıdı Lyrics\nBuralardan hemen...
# 2  5 ContributorsYaz Yaz Yaz LyricsDuygular var h...
# 3  2 ContributorsPırlanta LyricsParan cebinde kal...
# 4  5 ContributorsHadi Bakalım Lyrics\n\nYerimiz m...
#
#                                         temiz_lyrics
# 0  kuzu kuzu bak kırıldı kolum kanadım olmadı tut...
# 1  çakkıdı buralardan hemen gidesim var yeniden b...
# 2  yaz yaz yaz duygular var zaman kolay paylaşılm...
# 3  pırlanta paran cebinde kalsın bırak artık raha...
# 4  hadi bakalım yerimiz mi dar yoksa yenimiz mi d...

# %%
df.to_csv("mutlu_temiz.csv", index=False)

# %%
from google.colab import files
files.download("mutlu_temiz.csv")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9d67fbd-2685-48ef-a1aa-358ee7d5f02a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9d67fbd-2685-48ef-a1aa-358ee7d5f02a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df_uzgun = pd.read_csv("uzgun.csv")
df_uzgun.head()
# Out:
#          artist                  song_title  \
# 0        Tarkan                 Dön Bebeğim
# 1    Sezen Aksu                     Gidemem
# 2    Emre Aydın             Afili Yalnızlık
# 3        Gripin  Sensiz İstanbul’a Düşmanım
# 4  Mor ve Ötesi              Bir Derdim Var
#
#                                               lyrics   mood
# 0  8 ContributorsDön Bebeğim Lyrics\n\nSensiz gec...  üzgün
# 1  6 ContributorsGidemem Lyrics\n\nBazen daha faz...  üzgün
# 2  1 ContributorAfili yalnızlık Lyrics\n\nÖlsem (...  üzgün
# 3  1 ContributorSensiz İstanbul’a Düşmanım Lyrics...  üzgün
# 4  25 ContributorsBir Derdim Var Lyrics\n\nBir de...  üzgün

# %%
df_uzgun["temiz_lyrics"] = df_uzgun["lyrics"].apply(temizle)
df_uzgun[["lyrics", "temiz_lyrics"]].head()
# Out:
#                                               lyrics  \
# 0  8 ContributorsDön Bebeğim Lyrics\n\nSensiz gec...
# 1  6 ContributorsGidemem Lyrics\n\nBazen daha faz...
# 2  1 ContributorAfili yalnızlık Lyrics\n\nÖlsem (...
# 3  1 ContributorSensiz İstanbul’a Düşmanım Lyrics...
# 4  25 ContributorsBir Derdim Var Lyrics\n\nBir de...
#
#                                         temiz_lyrics
# 0  dön bebeğim sensiz gecelerin koynunda uyku gir...
# 1  gidemem bazen fazladır bir eşikten atlar insan...
# 2  contributorafili yalnızlık ölsem ölsem ölsem ö...
# 3  ensiz i̇stanbul’a düşmanım kelimelerden alacak...
# 4  bir derdim var bir derdim var artık tutamam iç...

# %%
df_uzgun.to_csv("uzgun_temiz.csv", index=False)

# %%
from google.colab import files
files.download("uzgun_temiz.csv")
